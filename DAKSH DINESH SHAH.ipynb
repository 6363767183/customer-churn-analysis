# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Admin'

# %%
os.chdir("C:/Users/Admin")

# %%
data=pd.read_csv("Customer Churn.csv")

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
#replacing blank with 0 and tensure 0 and total charges are recorded

# %%
data["TotalCharges"]=data["TotalCharges"].replace(" ","0")
data["TotalCharges"]=data["TotalCharges"].astype("float")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        0.162147    32.371149       64.761692   2279.734304
# std         0.368612    24.559481       30.090047   2266.794470
# min         0.000000     0.000000       18.250000      0.000000
# 25%         0.000000     9.000000       35.500000    398.550000
# 50%         0.000000    29.000000       70.350000   1394.550000
# 75%         0.000000    55.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000

# %%
data["customerID"].duplicated().sum()
# Out:
# 0

# %%
data["gender"].duplicated().sum()
# Out:
# 7041

# %% [raw]
# data.head()

# %%
data.head(10)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 5  9305-CDSKC  Female              0      No         No       8          Yes
# 6  1452-KIOVK    Male              0      No        Yes      22          Yes
# 7  6713-OKOMC  Female              0      No         No      10           No
# 8  7892-POOKP  Female              0     Yes         No      28          Yes
# 9  6388-TABGU    Male              0      No        Yes      62          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# ...

# %%
data["customerID"].duplicated().sum()
# Out:
# 0

# %%
# now here what we have did we have converted the dataset from 0 and 1 to yes or no to make it easier

# %%
def conv(value):
    if value  ==1:
        return "yes"
    else:
        return "no"

data["SeniorCitizen"]=data["SeniorCitizen"].apply(conv)

# %% [markdown]
# # now here what we have did we have converted the dataset from 0 and 1 to yes or no to make it easier

# %%
data.head(30)
# Out:
#     customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   7590-VHVEG  Female            no     Yes         No       1           No
# 1   5575-GNVDE    Male            no      No         No      34          Yes
# 2   3668-QPYBK    Male            no      No         No       2          Yes
# 3   7795-CFOCW    Male            no      No         No      45           No
# 4   9237-HQITU  Female            no      No         No       2          Yes
# 5   9305-CDSKC  Female            no      No         No       8          Yes
# 6   1452-KIOVK    Male            no      No        Yes      22          Yes
# 7   6713-OKOMC  Female            no      No         No      10           No
# 8   7892-POOKP  Female            no     Yes         No      28          Yes
# 9   6388-TABGU    Male            no      No        Yes      62          Yes
# 10  9763-GRSKD    Male            no     Yes        Yes      13          Yes
# ...

# %%
ax =sns.countplot(x = "Churn", data =data)


ax.bar_label(ax.containers[0])
plt.title("count of customers by Churn")
plt.show(ax)

# %%
pie chart

# %%
plt.figure(figsize=(4,4))
gb=data.groupby('Churn').agg({'Churn' : "count"})
plt.pie(gb['Churn'],labels=gb.index, autopct= "%1.2f%%") 
plt.title("percentage of churned customer")
plt.show()

# %% [markdown]
# # from the given pie chart we can mention it that 26.54% of people have churn out
# # now lets explore the reason behind it

# %%
plt.figure(figsize=(5,5))
sns.countplot( x='gender',data=data,hue ="Churn")
plt.title("churn by gender")
plt.show()

# %%
plt.figure(figsize=(5,5))
ax=sns.countplot( x='SeniorCitizen',data=data,hue ="Churn")
ax.bar_label(ax.containers[0])
plt.title("count of customer by SeniorCitizen")
plt.show(ax)

# %%
plt.figure(figsize=(9,4))
sns.histplot(x="tenure",data=data,bins =72,hue ="Churn")
plt.show()
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #in this we can see that people used our services for long time have been stayed and people who have been stayed for 1 or 2 month have churned out due to contract

# %%
plt.figure(figsize=(5,5))
ax=sns.countplot( x='Contract',data=data,hue="Churn")
ax.bar_label(ax.containers[0])
plt.title("count of customer by Contract")
plt.show(ax)

# %% [markdown]
# # people who have month to month contract are likely to churn from those who have 1 or 2 year of contract

# %%
data.columns.values
# Out:
# array(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'Churn'], dtype=object)

# %%
columns = ['PhoneService', 'MultipleLines', 'InternetService',
           'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
           'TechSupport', 'StreamingTV', 'StreamingMovies']

# Set the aesthetic style of the plots
sns.set(style="whitegrid")

# Create a figure with multiple subplots
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(15, 15))

# Flatten the axes array for easy iteration
axes = axes.flatten()

for i, col in enumerate(columns):
    sns.countplot(data=data, x=col, ax=axes[i],hue ="Churn")
    axes[i].set_title(f'Count plot of {col}')
    axes[i].set_xlabel('')
    axes[i].set_ylabel('Count')

# Adjust the layout
plt.tight_layout()
plt.show()

# %% [markdown]
# #THE MAJORITY OF CUSTOMERS WHO DO NOT CHURN TEND TO HAVE SERVICES LIKE PHONE SERVICES TEND TO HAVR SERVICES LIKE PHONE SERVICE ,INTERNET SERVICE PARTICULARY DSA AND ONLINE SECURITY ENABLED FOR SERVICES LIKE ONLINE BACKUP,TECH SUPPORTAND STREAMING TV ,CHURN RATE ARE HIGHER WHEN THSES SERVICE ARE NOT USED OR NOT AVILABLE

# %%
plt.figure(figsize=(10,10))
ax=sns.countplot( x='PaymentMethod',data=data,hue ="Churn")
ax.bar_label(ax.containers[0])
plt.title("churn of customer by PaymentMethod")
plt.show(ax)

# %% [markdown]
# # customer is likely to churn when he is using electronic check as payment method
